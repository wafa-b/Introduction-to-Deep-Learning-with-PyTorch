# %% [markdown]
# # Creating a Filter, Edge Detection

# %% [markdown]
# ###### Import resources and display image

# %%
#Import librires
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np
# %matplotlib inline
#Read Image
image=mpimg.imread('data/curved_lane.jpg')
#Show image
plt.imshow(image)

# %% [markdown]
# ###### Convert the image to grayscale

# %%
#Convert image to grayscale for filtering
gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
#Show image
plt.imshow(gray,cmap='gray')

# %% [markdown]
# ###### Create a custom kernel
# Common type of edge detection filter is a Sobel operator.
# The Sobel filter is very commonly used in edge detection and in finding patterns in intensity in an image. Applying a Sobel filter to an image is a way of taking (an approximation) of the derivative of the image in the x or y direction, separately.

# %%
#Create a custom kernel
#3x3 array for edge detection
sobel_y=np.array([[-1,-2,-1], 
                   [0,0,0], 
                   [1,2,1]])

#Create and apply a Sobel x operator
sobel_x=np.array([[-1,0,1],
                [-2,0,2],
                [-1,0,1]])

#Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image=cv2.filter2D(gray,-1,sobel_y)
filtered_image_2=cv2.filter2D(gray,-1,sobel_x)
#Show sobel_y image
plt.imshow(filtered_image,cmap='gray')
plt.title("sobel y")
plt.show()
#Show sobel_x image
plt.imshow(filtered_image_2,cmap='gray')
plt.title('Sobel x')
plt.show()

# %% [markdown]
# ###### Test out other filters!
#
# You're encouraged to create other kinds of filters and apply them to see what happens! As an **optional exercise**, try the following:
# * Create a filter with decimal value weights.
# * Create a 5x5 filter
# * Apply your filters to the other images in the `images` directory.

# %%
#Read image
image2=mpimg.imread('data/white_lines.jpg')
#Show image
plt.imshow(image2)

# %%
#Convert image to grayscale for filtering
gray2=cv2.cvtColor(image2,cv2.COLOR_RGB2GRAY)
#Show image
plt.imshow(gray2,cmap='gray')

# %%
#5x5 filter with decimal value weights array for edge detection
sobel_decimal=np.array([[-1,-1,-2.5,-1,-1],
                        [-1,-1,-2.5,-1,-1],
                        [0,0,0,0,0],
                        [1,1,2.5,1,1],
                        [1,1,2.5,1,1]])
#Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image2=cv2.filter2D(gray2,-1,sobel_decimal)
#Show image
plt.title("5x5 filter with decimal value weights array ")
plt.imshow(filtered_image2,cmap='gray')
